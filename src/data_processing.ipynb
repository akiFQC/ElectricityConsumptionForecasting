# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/household_power_consumption.txt", sep=";", parse_dates=[[0, 1]], na_values='?')

# %%
df.head(20)
# Out:
#              Date_Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  2006-12-16 17:24:00                4.216                  0.418   234.84
# 1  2006-12-16 17:25:00                5.360                  0.436   233.63
# 2  2006-12-16 17:26:00                5.374                  0.498   233.29
# 3  2006-12-16 17:27:00                5.388                  0.502   233.74
# 4  2006-12-16 17:28:00                3.666                  0.528   235.68
# 5  2006-12-16 17:29:00                3.520                  0.522   235.02
# 6  2006-12-16 17:30:00                3.702                  0.520   235.09
# 7  2006-12-16 17:31:00                3.700                  0.520   235.22
# 8  2006-12-16 17:32:00                3.668                  0.510   233.99
# 9  2006-12-16 17:33:00                3.662                  0.510   233.86
# 10 2006-12-16 17:34:00                4.448                  0.498   232.86
# ...

# %%
df.dtypes
# Out:
# Date_Time                datetime64[ns]
# Global_active_power             float64
# Global_reactive_power           float64
# Voltage                         float64
# Global_intensity                float64
# Sub_metering_1                  float64
# Sub_metering_2                  float64
# Sub_metering_3                  float64
# dtype: object

# %%
df[df["Date_Time"]=="2007-4-28 17:24:00"]
# Out:
#                  Date_Time  Global_active_power  Global_reactive_power  \
# 191520 2007-04-28 17:24:00                  NaN                    NaN
#
#         Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 191520      NaN               NaN             NaN             NaN
#
#         Sub_metering_3
# 191520             NaN

# %%
df.info
# Out:
# Date_Time                datetime64[ns]
# Global_active_power             float64
# Global_reactive_power           float64
# Voltage                         float64
# Global_intensity                float64
# Sub_metering_1                  float64
# Sub_metering_2                  float64
# Sub_metering_3                  float64
# dtype: object

# %%
df.to_csv("../data/HEC_processed.csv", index=False)
